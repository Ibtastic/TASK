# %%
# !pip install pydicom
# Out:
# Collecting pydicom
#   Downloading https://files.pythonhosted.org/packages/f0/8f/0e38dc0bcaf81170e3e6a53c23a0ceb70d9991c7ec887245981b36f18358/pydicom-1.2.1-py2.py3-none-any.whl (7.0MB)
#     100% |████████████████████████████████| 7.0MB 6.5MB/s
# Installing collected packages: pydicom
# Successfully installed pydicom-1.2.1

# %%
import pydicom

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('ttfm.dcm','wb').write(src)
# Out:
#      <input type="file" id="files-d59cb09f-2a40-4f38-b4e2-316f6b431298" name="files[]" multiple disabled />
#      <output id="result-d59cb09f-2a40-4f38-b4e2-316f6b431298">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ttfm.dcm to ttfm.dcm
# 348934

# %%
ds = pydicom.dcmread('ttfm.dcm')

# %%
ds.dir()
# Out:
# ['AccessionNumber',
#  'BitsAllocated',
#  'BitsStored',
#  'CineRate',
#  'Columns',
#  'ContentDate',
#  'ContentTime',
#  'DeviceSerialNumber',
#  'EffectiveDuration',
#  'FrameIncrementPointer',
#  'FrameTime',
#  'HighBit',
#  'ImageComments',
#  'ImageType',
#  'InstanceNumber',
#  'InstitutionAddress',
#  'InstitutionName',
#  'Laterality',
#  'LossyImageCompression',
#  'Manufacturer',
#  'ManufacturerModelName',
#  'Modality',
#  'NumberOfFrames',
#  'PatientBirthDate',
#  'PatientComments',
#  'PatientID',
#  'PatientName',
#  'PatientOrientation',
#  'PatientSex',
#  'PatientSize',
#  'PatientWeight',
#  'PerformingPhysicianName',
#  'PhotometricInterpretation',
#  'PixelData',
#  'PixelRepresentation',
#  'PlanarConfiguration',
#  'PreferredPlaybackSequencing',
#  'RecommendedDisplayFrameRate',
#  'ReferringPhysicianName',
#  'Rows',
#  'SOPClassUID',
#  'SOPInstanceUID',
#  'SamplesPerPixel',
#  'SequenceOfUltrasoundRegions',
#  'SeriesDate',
#  'SeriesInstanceUID',
#  'SeriesNumber',
#  'SeriesTime',
#  'SoftwareVersions',
#  'SpecificCharacterSet',
#  'StationName',
#  'StudyDate',
#  'StudyDescription',
#  'StudyID',
#  'StudyInstanceUID',
#  'StudyTime']

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('bmode.dcm','wb').write(src)
# Out:
#      <input type="file" id="files-419d2b78-ef8d-49aa-b052-fb76b121b4fb" name="files[]" multiple disabled />
#      <output id="result-419d2b78-ef8d-49aa-b052-fb76b121b4fb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bmode.dcm to bmode.dcm
# 27473814

# %%
ds2 = pydicom.dcmread('bmode.dcm')

# %%
ds2.dir()
# Out:
# ['AccessionNumber',
#  'BitsAllocated',
#  'BitsStored',
#  'CineRate',
#  'Columns',
#  'ContentDate',
#  'ContentTime',
#  'DeviceSerialNumber',
#  'EffectiveDuration',
#  'FrameIncrementPointer',
#  'FrameTime',
#  'HighBit',
#  'ImageComments',
#  'ImageType',
#  'InstanceNumber',
#  'InstitutionAddress',
#  'InstitutionName',
#  'Laterality',
#  'LossyImageCompression',
#  'Manufacturer',
#  'ManufacturerModelName',
#  'Modality',
#  'NumberOfFrames',
#  'PatientBirthDate',
#  'PatientComments',
#  'PatientID',
#  'PatientName',
#  'PatientOrientation',
#  'PatientSex',
#  'PatientSize',
#  'PatientWeight',
#  'PerformingPhysicianName',
#  'PhotometricInterpretation',
#  'PixelData',
#  'PixelRepresentation',
#  'PlanarConfiguration',
#  'PreferredPlaybackSequencing',
#  'RecommendedDisplayFrameRate',
#  'ReferringPhysicianName',
#  'Rows',
#  'SOPClassUID',
#  'SOPInstanceUID',
#  'SamplesPerPixel',
#  'SequenceOfUltrasoundRegions',
#  'SeriesDate',
#  'SeriesInstanceUID',
#  'SeriesNumber',
#  'SeriesTime',
#  'SoftwareVersions',
#  'SpecificCharacterSet',
#  'StationName',
#  'StudyDate',
#  'StudyDescription',
#  'StudyID',
#  'StudyInstanceUID',
#  'StudyTime']
